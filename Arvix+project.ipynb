# %%
'''
* Program: Fetch meta data from arxiv for data analysis in XMl form
* By Neel Shah
* date: 3/3/2017
* Note: Anyone can use this code for their research, just share it who need it.
'''
import sys
import urllib.request

#it is used for retriving of data from arxiv website
def get_MetaData(start,end):
    print(start)
    print(end)
    try:
        #It is query which we fire to arxiv api with different parameter like CV, CS,AI etc.
        url = 'http://export.arxiv.org/api/query?search_query=cat:cs.CV%20OR%20cat:cs.AI%20OR%20cat:cs.LG%20OR%20cat:cs.CL%20OR%20cat:cs.NE%20OR%20cat:stat.ML&id_list=&start='+str(start)+'&max_results='+str(end)
        data = urllib.request.urlopen(url).read()
        #return the data we get from query
        return data
    except:
        print('Error in retriving of data from '+str(url))
        return False

def store_MetaData(data):
    try:
        #Where file is stored
        file = open(r'/home/neel/arxiv_data/test_data.xml','w+',encoding='utf8')
        file.write(str(data))
        file.close()
    except IOError as e:
        print('Error in writing file.'+str(e))
    
def main():
    #to limit the download of data
    loop_count=0
    #to count how many paper's data we get
    paper_count=10
    #it is used in query to know from where to start download paper
    start_num=0
    #it is used in query to know from where to end download paper
    end_num=10
    while loop_count < 2600:
        #fetching mata data
        meta_data=get_MetaData(start_num,end_num)
        if meta_data != False:
            #write meta data to XML file
            store_MetaData(meta_data)
            print("Total number of paper store: "+str(paper_count))
            start_num=end_num+1
            end_num=end_num+10
        else:
            print('Error occure: you have to start download from '+str(start_num))
    return None

if __name__=='__main__':
    main()
# Out:
# 0
# 10
# Total number of paper store: 10
# 11
# 20
# Total number of paper store: 10
# 21
# 30
# Total number of paper store: 10
# 31
# 40
# Total number of paper store: 10
# 41
# 50
# Total number of paper store: 10
# 51
# 60
# Total number of paper store: 10
# 61
# 70
# Total number of paper store: 10
# 71
# 80
# Total number of paper store: 10
# 81
# 90
# Total number of paper store: 10
# 91
# 100
# Total number of paper store: 10
# 101
# 110
# Total number of paper store: 10
# 111
# 120
# Total number of paper store: 10
# 121
# 130
# Total number of paper store: 10
# 131
# 140
# Total number of paper store: 10
# 141
# 150
# Total number of paper store: 10
# 151
# 160
# Total number of paper store: 10
# 161
# 170
# Total number of paper store: 10
# 171
# 180
# Total number of paper store: 10
# 181
# 190
# Total number of paper store: 10
# 191
# 200
# Total number of paper store: 10
# 201
# 210
# Total number of paper store: 10
# 211
# 220
# Total number of paper store: 10
# 221
# 230
# Total number of paper store: 10
# 231
# 240
# Total number of paper store: 10
# 241
# 250
# Total number of paper store: 10
# 251
# 260
# Total number of paper store: 10
# 261
# 270
# Total number of paper store: 10
# 271
# 280
# Total number of paper store: 10
# 281
# 290
# Total number of paper store: 10
# 291
# 300
# Total number of paper store: 10
# 301
# 310
# Total number of paper store: 10
# 311
# 320
# Total number of paper store: 10
# 321
# 330
# Total number of paper store: 10
# 331
# 340
# Total number of paper store: 10
# 341
# 350
# Total number of paper store: 10
# 351
# 360
# Total number of paper store: 10
# 361
# 370
# Total number of paper store: 10
# 371
# 380
# Total number of paper store: 10
# 381
# 390
# Total number of paper store: 10
# 391
# 400
# Total number of paper store: 10
# 401
# 410
# Total number of paper store: 10
# 411
# 420
# Total number of paper store: 10
# 421
# 430
# Total number of paper store: 10
# 431
# 440
# Total number of paper store: 10
# 441
# 450
# Total number of paper store: 10
# 451
# 460
# Total number of paper store: 10
# 461
# 470
# Total number of paper store: 10
# 471
# 480
# Total number of paper store: 10
# 481
# 490
# Total number of paper store: 10
# 491
# 500
# Total number of paper store: 10
# 501
# 510
# Total number of paper store: 10
# 511
# 520
# Total number of paper store: 10
# 521
# 530
# Total number of paper store: 10
# 531
# 540
# Total number of paper store: 10
# 541
# 550
# Total number of paper store: 10
# 551
# 560
# Total number of paper store: 10
# 561
# 570
# Total number of paper store: 10
# 571
# 580
# Total number of paper store: 10
# 581
# 590
# Total number of paper store: 10
# 591
# 600
# Total number of paper store: 10
# 601
# 610
# Total number of paper store: 10
# 611
# 620
# Total number of paper store: 10
# 621
# 630
# Total number of paper store: 10
# 631
# 640
# Total number of paper store: 10
# 641
# 650
# Total number of paper store: 10
# 651
# 660
# Total number of paper store: 10
# 661
# 670
# Total number of paper store: 10
# 671
# 680
# Total number of paper store: 10
# 681
# 690
# Total number of paper store: 10
# 691
# 700
# Total number of paper store: 10
# 701
# 710
# Total number of paper store: 10
# 711
# 720
# Total number of paper store: 10
# 721
# 730
# Total number of paper store: 10
# 731
# 740
# Total number of paper store: 10
# 741
# 750
# Total number of paper store: 10
# 751
# 760
# Total number of paper store: 10
# 761
# 770
# Total number of paper store: 10
# 771
# 780
# Total number of paper store: 10
# 781
# 790
# Total number of paper store: 10
# 791
# 800
# Total number of paper store: 10
# 801
# 810
# Total number of paper store: 10
# 811
# 820
# Total number of paper store: 10
# 821
# 830
# Total number of paper store: 10
# 831
# 840
# Total number of paper store: 10
# 841
# 850
# Total number of paper store: 10
# 851
# 860
# Total number of paper store: 10
# 861
# 870
# Total number of paper store: 10
# 871
# 880
# Total number of paper store: 10
# 881
# 890
# Total number of paper store: 10
# 891
# 900
# Total number of paper store: 10
# 901
# 910
# Total number of paper store: 10
# 911
# 920
# Total number of paper store: 10
# 921
# 930
# Total number of paper store: 10
# 931
# 940
# Total number of paper store: 10
# 941
# 950
# Total number of paper store: 10
# 951
# 960
# Total number of paper store: 10
# 961
# 970
# Total number of paper store: 10
# 971
# 980
# Total number of paper store: 10
# 981
# 990
# Total number of paper store: 10
# 991
# 1000
# Total number of paper store: 10
# 1001
# 1010
# Total number of paper store: 10
# 1011
# 1020
# Total number of paper store: 10
# 1021
# 1030
# Total number of paper store: 10
# 1031
# 1040
# Total number of paper store: 10
# 1041
# 1050
# Total number of paper store: 10
# 1051
# 1060
# Total number of paper store: 10
# 1061
# 1070
# Total number of paper store: 10
# 1071
# 1080
# Total number of paper store: 10
# 1081
# 1090
# Total number of paper store: 10
# 1091
# 1100
# Total number of paper store: 10
# 1101
# 1110
# Total number of paper store: 10
# 1111
# 1120
# Total number of paper store: 10
# 1121
# 1130
# Total number of paper store: 10
# 1131
# 1140
# Total number of paper store: 10
# 1141
# 1150
# Total number of paper store: 10
# 1151
# 1160
# Total number of paper store: 10
# 1161
# 1170
# Total number of paper store: 10
# 1171
# 1180
# Total number of paper store: 10
# 1181
# 1190

# %%
import os

print(os.getcwd())
